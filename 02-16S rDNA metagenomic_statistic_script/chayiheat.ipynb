# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import os
import PyComplexHeatmap as pchm

# %%
#读取文件
df = pd.read_csv('newwsample2.txt',sep='\t')
df.head()
# Out:
#                                       groups  HC-1-pre  HC-2-pre  HC-3-pre  \
# 0                       Acidovorax sp. MR-S7  0.003129  0.001692  0.005346
# 1                  Acinetobacter sp. 1578804  0.000908  0.000532  0.003437
# 2             Actinomyces dentalis DSM 19115  0.000163  0.006459  0.006000
# 3                      Actinomyces sp. ICM47  0.025993  0.009780  0.129033
# 4  Actinomyces sp. oral taxon 180 str. F0310  0.000505  0.004907  0.004387
#
#    OSCC-1-pre  OSCC-2-pre  OSCC-3-pre  OSCC-4-pre  HC-1-post  HC-2-post  \
# 0    0.000000    0.008032    0.000000    0.009702   0.000266   0.000000
# 1    0.000000    0.012538    0.001411    0.001305   0.002766   0.000738
# 2    0.004576    0.000000    0.021742    0.038357   0.000340   0.000000
# 3    0.000719    0.005167    0.001578    0.000352   0.010164   0.001300
# 4    0.000000    0.005223    0.032384    0.001295   0.000952   0.000836
#
#    HC-3-post  OSCC-1-post  OSCC-2-post  OSCC-3-post  OSCC-4-post
# ...

# %%
df2=df[['groups', 'HC-1-pre', 'HC-2-pre','HC-3-pre','OSCC-1-pre', 
         'OSCC-2-pre','OSCC-3-pre','OSCC-4-pre','HC-1-post','HC-2-post',  'HC-3-post',
'OSCC-1-post','OSCC-2-post','OSCC-3-post',  'OSCC-4-post']]
df2
# Out:
#                                         groups  HC-1-pre  HC-2-pre  HC-3-pre  \
# 0                         Acidovorax sp. MR-S7  0.003129  0.001692  0.005346
# 1                    Acinetobacter sp. 1578804  0.000908  0.000532  0.003437
# 2               Actinomyces dentalis DSM 19115  0.000163  0.006459  0.006000
# 3                        Actinomyces sp. ICM47  0.025993  0.009780  0.129033
# 4    Actinomyces sp. oral taxon 180 str. F0310  0.000505  0.004907  0.004387
# ..                                         ...       ...       ...       ...
# 104                  Streptomyces griseorubens  0.005394  0.005589  0.042350
# 105                Tyzzerella nexilis DSM 1787  0.020114  0.000000  0.000000
# 106                     Veillonella sp. 3_1_44  0.017882  0.000000  0.000000
# 107                     Veillonella sp. 6_1_27  0.001250  0.013667  0.008315
# 108                     Veillonella sp. ICM51a  0.014210  0.002008  0.001763
#
# ...

# %%
#df2以groups列为索引
df3 = df2.set_index('groups')
df3
# Out:
#                                            HC-1-pre  HC-2-pre  HC-3-pre  \
# groups
# Acidovorax sp. MR-S7                       0.003129  0.001692  0.005346
# Acinetobacter sp. 1578804                  0.000908  0.000532  0.003437
# Actinomyces dentalis DSM 19115             0.000163  0.006459  0.006000
# Actinomyces sp. ICM47                      0.025993  0.009780  0.129033
# Actinomyces sp. oral taxon 180 str. F0310  0.000505  0.004907  0.004387
# ...                                             ...       ...       ...
# Streptomyces griseorubens                  0.005394  0.005589  0.042350
# Tyzzerella nexilis DSM 1787                0.020114  0.000000  0.000000
# Veillonella sp. 3_1_44                     0.017882  0.000000  0.000000
# Veillonella sp. 6_1_27                     0.001250  0.013667  0.008315
# Veillonella sp. ICM51a                     0.014210  0.002008  0.001763
#
#                                            OSCC-1-pre  OSCC-2-pre  OSCC-3-pre  \
# groups
# ...

# %%
#data1保存到txt文件
df2.to_csv('data1.txt',sep='\t',index=False)

# %%
df9 = pd.read_table('stat_res_eh_vs_eo1.csv',sep=',',index_col=0)
df9
# Out:
#                                               baseMean  log2FoldChange  \
# groups
# Acidovorax sp. MR-S7                       2029.044169        0.038389
# Acinetobacter sp. 1578804                  1115.539469       -1.187839
# Actinomyces dentalis DSM 19115             3183.176031       -2.738705
# Actinomyces sp. ICM47                       895.496360        3.949080
# Actinomyces sp. oral taxon 180 str. F0310  3437.728398       -2.971263
# ...                                                ...             ...
# Streptomyces griseorubens                  1327.653358        1.110687
# Tyzzerella nexilis DSM 1787                 698.506658        4.243948
# Veillonella sp. 3_1_44                      749.595686       20.673165
# Veillonella sp. 6_1_27                     1716.443255       -3.184755
# Veillonella sp. ICM51a                      768.492388        7.091172
#
#                                               lfcSE      stat    pvalue  \
# groups
# ...

# %%
df9.loc[(df9.log2FoldChange>1)&(df9.padj<0.05),'type']='up'
df9.loc[(df9.log2FoldChange<-1)&(df9.padj<0.05),'type']='down'
df9.loc[(abs(df9.log2FoldChange)<=1)|(df9.padj>=0.05),'type']='nosig'
df9.head()
# Out:
#                                               baseMean  log2FoldChange  \
# groups
# Acidovorax sp. MR-S7                       2029.044169        0.038389
# Acinetobacter sp. 1578804                  1115.539469       -1.187839
# Actinomyces dentalis DSM 19115             3183.176031       -2.738705
# Actinomyces sp. ICM47                       895.496360        3.949080
# Actinomyces sp. oral taxon 180 str. F0310  3437.728398       -2.971263
#
#                                               lfcSE      stat    pvalue  \
# groups
# Acidovorax sp. MR-S7                       2.006764  0.019130  0.984738
# Acinetobacter sp. 1578804                  1.752268 -0.677886  0.497844
# Actinomyces dentalis DSM 19115             1.985413 -1.379413  0.167767
# Actinomyces sp. ICM47                      1.502581  2.628197  0.008584
# Actinomyces sp. oral taxon 180 str. F0310  2.036442 -1.459046       NaN
#
#                                                padj   type
# groups
# ...

# %%
data1=df9

# %%
left1=data1
right1=df3
df10=pd.merge(left1, right1,on='groups')
df10
# Out:
#                                               baseMean  log2FoldChange  \
# groups
# Acidovorax sp. MR-S7                       2029.044169        0.038389
# Acinetobacter sp. 1578804                  1115.539469       -1.187839
# Actinomyces dentalis DSM 19115             3183.176031       -2.738705
# Actinomyces sp. ICM47                       895.496360        3.949080
# Actinomyces sp. oral taxon 180 str. F0310  3437.728398       -2.971263
# ...                                                ...             ...
# Streptomyces griseorubens                  1327.653358        1.110687
# Tyzzerella nexilis DSM 1787                 698.506658        4.243948
# Veillonella sp. 3_1_44                      749.595686       20.673165
# Veillonella sp. 6_1_27                     1716.443255       -3.184755
# Veillonella sp. ICM51a                      768.492388        7.091172
#
#                                               lfcSE      stat    pvalue  \
# groups
# ...

# %%
#筛选df12中type的up和down的行
df13=df10[(df10.type=='up')|(df10.type=='down')]
df13
# Out:
#                                     baseMean  log2FoldChange     lfcSE  \
# groups
# Eikenella corrodens CC92I         572.802704      -10.526085  1.975581
# Mesorhizobium sp. LSJC265A00      676.740088      -10.767776  1.962675
# Prevotella aurantiaca JCM 15754  2024.510903       12.184582  1.661282
# Prevotella intermedia 17         2032.176973        8.354306  1.749847
# Rhizobium vignae                 3313.799310      -13.082912  1.681545
# Veillonella sp. ICM51a            768.492388        7.091172  1.825504
#
#                                      stat        pvalue          padj  type  \
# groups
# Eikenella corrodens CC92I       -5.328097  9.924699e-08  1.811258e-06  down
# Mesorhizobium sp. LSJC265A00    -5.486277  4.104937e-08  9.988680e-07  down
# Prevotella aurantiaca JCM 15754  7.334444  2.226439e-13  8.126501e-12    up
# Prevotella intermedia 17         4.774305  1.803285e-06  2.632796e-05    up
# ...

# %%
df15=df13[['type','HC-1-pre', 'HC-2-pre','HC-3-pre','OSCC-1-pre', 
         'OSCC-2-pre','OSCC-3-pre','OSCC-4-pre']]
df15
# Out:
#                                  type  HC-1-pre  HC-2-pre  HC-3-pre  \
# groups
# Eikenella corrodens CC92I        down  0.000000  0.000000  0.000000
# Mesorhizobium sp. LSJC265A00     down  0.000000  0.000000  0.000000
# Prevotella aurantiaca JCM 15754    up  0.017227  0.028010  0.038742
# Prevotella intermedia 17           up  0.008800  0.011247  0.015976
# Rhizobium vignae                 down  0.000000  0.000000  0.000000
# Veillonella sp. ICM51a             up  0.014210  0.002008  0.001763
#
#                                  OSCC-1-pre  OSCC-2-pre  OSCC-3-pre  \
# groups
# Eikenella corrodens CC92I          0.000933    0.001378    0.000000
# Mesorhizobium sp. LSJC265A00       0.000682    0.020663    0.000000
# Prevotella aurantiaca JCM 15754    0.000000    0.000000    0.000000
# Prevotella intermedia 17           0.000000    0.000299    0.000000
# Rhizobium vignae                   0.005901    0.031169    0.017905
# ...

# %%
#检查df15中索引是否有重复
df15.index.is_unique
# Out:
# True

# %%
df15
# Out:
#                                  type  HC-1-pre  HC-2-pre  HC-3-pre  \
# groups
# Eikenella corrodens CC92I        down  0.000000  0.000000  0.000000
# Mesorhizobium sp. LSJC265A00     down  0.000000  0.000000  0.000000
# Prevotella aurantiaca JCM 15754    up  0.017227  0.028010  0.038742
# Prevotella intermedia 17           up  0.008800  0.011247  0.015976
# Rhizobium vignae                 down  0.000000  0.000000  0.000000
# Veillonella sp. ICM51a             up  0.014210  0.002008  0.001763
#
#                                  OSCC-1-pre  OSCC-2-pre  OSCC-3-pre  \
# groups
# Eikenella corrodens CC92I          0.000933    0.001378    0.000000
# Mesorhizobium sp. LSJC265A00       0.000682    0.020663    0.000000
# Prevotella aurantiaca JCM 15754    0.000000    0.000000    0.000000
# Prevotella intermedia 17           0.000000    0.000299    0.000000
# Rhizobium vignae                   0.005901    0.031169    0.017905
# ...

# %%
df11=df15[['HC-1-pre', 'HC-2-pre','HC-3-pre','OSCC-1-pre', 
         'OSCC-2-pre','OSCC-3-pre','OSCC-4-pre']]
df11
# Out:
#                                  HC-1-pre  HC-2-pre  HC-3-pre  OSCC-1-pre  \
# groups
# Eikenella corrodens CC92I        0.000000  0.000000  0.000000    0.000933
# Mesorhizobium sp. LSJC265A00     0.000000  0.000000  0.000000    0.000682
# Prevotella aurantiaca JCM 15754  0.017227  0.028010  0.038742    0.000000
# Prevotella intermedia 17         0.008800  0.011247  0.015976    0.000000
# Rhizobium vignae                 0.000000  0.000000  0.000000    0.005901
# Veillonella sp. ICM51a           0.014210  0.002008  0.001763    0.000000
#
#                                  OSCC-2-pre  OSCC-3-pre  OSCC-4-pre
# groups
# Eikenella corrodens CC92I          0.001378    0.000000    0.006480
# Mesorhizobium sp. LSJC265A00       0.020663    0.000000    0.004374
# Prevotella aurantiaca JCM 15754    0.000000    0.000000    0.000000
# Prevotella intermedia 17           0.000299    0.000000    0.000000
# Rhizobium vignae                   0.031169    0.017905    0.024113
# ...

# %%
data0=np.log2(df11+0.00001)
data0
# Out:
#                                   HC-1-pre   HC-2-pre   HC-3-pre  OSCC-1-pre  \
# groups
# Eikenella corrodens CC92I       -16.609640 -16.609640 -16.609640  -10.050611
# Mesorhizobium sp. LSJC265A00    -16.609640 -16.609640 -16.609640  -10.497631
# Prevotella aurantiaca JCM 15754  -5.858376  -5.157377  -4.689570  -16.609640
# Prevotella intermedia 17         -6.826633  -6.473063  -5.967076  -16.609640
# Rhizobium vignae                -16.609640 -16.609640 -16.609640   -7.402395
# Veillonella sp. ICM51a           -6.135936  -8.952509  -9.139877  -16.609640
#
#                                  OSCC-2-pre  OSCC-3-pre  OSCC-4-pre
# groups
# Eikenella corrodens CC92I         -9.492902  -16.609640   -7.267507
# Mesorhizobium sp. LSJC265A00      -5.596079  -16.609640   -7.833662
# Prevotella aurantiaca JCM 15754  -16.609640  -16.609640  -16.609640
# Prevotella intermedia 17         -11.657808  -16.609640  -16.609640
# Rhizobium vignae                  -5.003299   -5.802715   -5.373445
# ...

# %%
df16=df15[['type']]
df16
# Out:
#                                  type
# groups
# Eikenella corrodens CC92I        down
# Mesorhizobium sp. LSJC265A00     down
# Prevotella aurantiaca JCM 15754    up
# Prevotella intermedia 17           up
# Rhizobium vignae                 down
# Veillonella sp. ICM51a             up

# %%
#df16的type列名称改为P&log2FC
df16.columns=['Change']
data_rows=df16
data_rows
# Out:
#                                 Change
# groups
# Eikenella corrodens CC92I         down
# Mesorhizobium sp. LSJC265A00      down
# Prevotella aurantiaca JCM 15754     up
# Prevotella intermedia 17            up
# Rhizobium vignae                  down
# Veillonella sp. ICM51a              up

# %%
data_cols=pd.read_csv('groupy2.tsv',index_col=0, sep='\t')
data_cols
# Out:
#                        Group
# sample
# HC-1-pre      HC-pre-culture
# HC-2-pre      HC-pre-culture
# HC-3-pre      HC-pre-culture
# OSCC-1-pre  OSCC-pre-culture
# OSCC-2-pre  OSCC-pre-culture
# OSCC-3-pre  OSCC-pre-culture
# OSCC-4-pre  OSCC-pre-culture

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import pandas as pd
import os
import PyComplexHeatmap as pchm
from PyComplexHeatmap import *

# %%
row_ha_left = HeatmapAnnotation(
                            Change =anno_simple(data_rows['Change'],colors={'up': 'red', 'down': 'green'},
                                                add_text=True,legend=False,height=5,
                                                text_kws={'color':'white', 'fontsize':12,'fontweight':'bold',
                                                          'rotation':-90,'horizontalalignment':'left'}),
                            label_kws={'fontsize':13,'color':'black','rotation':-45,'horizontalalignment':'left'},
                            label_side='bottom',axis=0,verbose=0
                            )
col_ha = HeatmapAnnotation(Group=data_cols.Group,label_side='right', axis=1,label_kws={'fontsize': 13})
plt.figure(figsize=(8, 5))
cm = ClusterMapPlotter(data=data0,left_annotation=row_ha_left,top_annotation=col_ha,
                       show_rownames=True, show_colnames=True,col_names_side='bottom',
                       row_split=data_rows.Change, cmap='YlGnBu',
                       rasterized=True, legend=True,
                       xticklabels_kws={'labelrotation':-20,'labelsize': 12}, yticklabels_kws={'labelsize': 11},row_dendrogram=True,col_dendrogram=True)
#添加标题HC-pre-culture vs OSCC-pre-culture
plt.title('HC-pre-culture vs OSCC-pre-culture', fontsize=17, loc='center', x=-29, y=4)
plt.savefig('heatmap of HC-pre-culture vs OSCC-pre-culture1.pdf',dpi=300,bbox_inches='tight')
plt.show()
# Out:
# Starting plotting..
# Starting calculating row orders..
# Reordering rows..
# Starting calculating col orders..
# Reordering cols..
# Plotting matrix..
# Starting plotting HeatmapAnnotations
# ...
# Plotting legends..
# Estimated legend width: 39.68888888888889 mm
