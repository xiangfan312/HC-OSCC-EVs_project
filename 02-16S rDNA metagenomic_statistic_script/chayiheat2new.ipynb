# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import os
import PyComplexHeatmap as pchm

# %%
#读取文件
df = pd.read_csv('newwsample2.txt',sep='\t')
df.head()
# Out:
#                                       groups  HC-1-pre  HC-2-pre  HC-3-pre  \
# 0                       Acidovorax sp. MR-S7  0.003129  0.001692  0.005346
# 1                  Acinetobacter sp. 1578804  0.000908  0.000532  0.003437
# 2             Actinomyces dentalis DSM 19115  0.000163  0.006459  0.006000
# 3                      Actinomyces sp. ICM47  0.025993  0.009780  0.129033
# 4  Actinomyces sp. oral taxon 180 str. F0310  0.000505  0.004907  0.004387
#
#    OSCC-1-pre  OSCC-2-pre  OSCC-3-pre  OSCC-4-pre  HC-1-post  HC-2-post  \
# 0    0.000000    0.008032    0.000000    0.009702   0.000266   0.000000
# 1    0.000000    0.012538    0.001411    0.001305   0.002766   0.000738
# 2    0.004576    0.000000    0.021742    0.038357   0.000340   0.000000
# 3    0.000719    0.005167    0.001578    0.000352   0.010164   0.001300
# 4    0.000000    0.005223    0.032384    0.001295   0.000952   0.000836
#
#    HC-3-post  OSCC-1-post  OSCC-2-post  OSCC-3-post  OSCC-4-post
# 0   0.000000     0.000061     0.000079     0.000000          0.0
# 1   0.002212     0.000000     0.002069     0.000000          0.0
# 2   0.000148     0.000135     0.000000     0.000093          0.0
# 3   0.014678     0.000000     0.000826     0.000226          0.0
# 4   0.001218     0.000086     0.000029     0.007072          0.0

# %%
df2=df[['groups', 'HC-1-pre', 'HC-2-pre','HC-3-pre','OSCC-1-pre', 
         'OSCC-2-pre','OSCC-3-pre','OSCC-4-pre','HC-1-post','HC-2-post',  'HC-3-post',
'OSCC-1-post','OSCC-2-post','OSCC-3-post',  'OSCC-4-post']]
df2
# Out:
#                                         groups  HC-1-pre  HC-2-pre  HC-3-pre  \
# 0                         Acidovorax sp. MR-S7  0.003129  0.001692  0.005346
# 1                    Acinetobacter sp. 1578804  0.000908  0.000532  0.003437
# 2               Actinomyces dentalis DSM 19115  0.000163  0.006459  0.006000
# 3                        Actinomyces sp. ICM47  0.025993  0.009780  0.129033
# 4    Actinomyces sp. oral taxon 180 str. F0310  0.000505  0.004907  0.004387
# ..                                         ...       ...       ...       ...
# 104                  Streptomyces griseorubens  0.005394  0.005589  0.042350
# 105                Tyzzerella nexilis DSM 1787  0.020114  0.000000  0.000000
# 106                     Veillonella sp. 3_1_44  0.017882  0.000000  0.000000
# 107                     Veillonella sp. 6_1_27  0.001250  0.013667  0.008315
# 108                     Veillonella sp. ICM51a  0.014210  0.002008  0.001763
#
#      OSCC-1-pre  OSCC-2-pre  OSCC-3-pre  OSCC-4-pre  HC-1-post  HC-2-post  \
# 0      0.000000    0.008032    0.000000    0.009702   0.000266   0.000000
# 1      0.000000    0.012538    0.001411    0.001305   0.002766   0.000738
# 2      0.004576    0.000000    0.021742    0.038357   0.000340   0.000000
# 3      0.000719    0.005167    0.001578    0.000352   0.010164   0.001300
# 4      0.000000    0.005223    0.032384    0.001295   0.000952   0.000836
# ..          ...         ...         ...         ...        ...        ...
# 104    0.002332    0.004618    0.003761    0.001960   0.000286   0.000154
# 105    0.000000    0.000000    0.000000    0.001963   0.034854   0.000000
# 106    0.000000    0.000000    0.000000    0.000000   0.027008   0.000000
# 107    0.004110    0.001141    0.087272    0.005661   0.002326   0.019633
# 108    0.000000    0.000417    0.000000    0.000000   0.026006   0.000085
#
#      HC-3-post  OSCC-1-post  OSCC-2-post  OSCC-3-post  OSCC-4-post
# 0     0.000000     0.000061     0.000079     0.000000     0.000000
# 1     0.002212     0.000000     0.002069     0.000000     0.000000
# 2     0.000148     0.000135     0.000000     0.000093     0.000000
# 3     0.014678     0.000000     0.000826     0.000226     0.000000
# 4     0.001218     0.000086     0.000029     0.007072     0.000000
# ..         ...          ...          ...          ...          ...
# 104   0.000485     0.000000     0.000000     0.000000     0.000000
# 105   0.000000     0.000000     0.000000     0.000000     0.000000
# 106   0.000000     0.000000     0.000000     0.000000     0.000000
# 107   0.007102     0.000699     0.006562     0.175269     0.012815
# 108   0.000726     0.000000     0.000530     0.000000     0.000000
#
# [109 rows x 15 columns]

# %%
#df2以groups列为索引
df3 = df2.set_index('groups')
df3
# Out:
#                                            HC-1-pre  HC-2-pre  HC-3-pre  \
# groups
# Acidovorax sp. MR-S7                       0.003129  0.001692  0.005346
# Acinetobacter sp. 1578804                  0.000908  0.000532  0.003437
# Actinomyces dentalis DSM 19115             0.000163  0.006459  0.006000
# Actinomyces sp. ICM47                      0.025993  0.009780  0.129033
# Actinomyces sp. oral taxon 180 str. F0310  0.000505  0.004907  0.004387
# ...                                             ...       ...       ...
# Streptomyces griseorubens                  0.005394  0.005589  0.042350
# Tyzzerella nexilis DSM 1787                0.020114  0.000000  0.000000
# Veillonella sp. 3_1_44                     0.017882  0.000000  0.000000
# Veillonella sp. 6_1_27                     0.001250  0.013667  0.008315
# Veillonella sp. ICM51a                     0.014210  0.002008  0.001763
#
#                                            OSCC-1-pre  OSCC-2-pre  OSCC-3-pre  \
# groups
# Acidovorax sp. MR-S7                         0.000000    0.008032    0.000000
# Acinetobacter sp. 1578804                    0.000000    0.012538    0.001411
# Actinomyces dentalis DSM 19115               0.004576    0.000000    0.021742
# Actinomyces sp. ICM47                        0.000719    0.005167    0.001578
# Actinomyces sp. oral taxon 180 str. F0310    0.000000    0.005223    0.032384
# ...                                               ...         ...         ...
# Streptomyces griseorubens                    0.002332    0.004618    0.003761
# Tyzzerella nexilis DSM 1787                  0.000000    0.000000    0.000000
# Veillonella sp. 3_1_44                       0.000000    0.000000    0.000000
# Veillonella sp. 6_1_27                       0.004110    0.001141    0.087272
# Veillonella sp. ICM51a                       0.000000    0.000417    0.000000
#
#                                            OSCC-4-pre  HC-1-post  HC-2-post  \
# groups
# Acidovorax sp. MR-S7                         0.009702   0.000266   0.000000
# Acinetobacter sp. 1578804                    0.001305   0.002766   0.000738
# Actinomyces dentalis DSM 19115               0.038357   0.000340   0.000000
# Actinomyces sp. ICM47                        0.000352   0.010164   0.001300
# Actinomyces sp. oral taxon 180 str. F0310    0.001295   0.000952   0.000836
# ...                                               ...        ...        ...
# Streptomyces griseorubens                    0.001960   0.000286   0.000154
# Tyzzerella nexilis DSM 1787                  0.001963   0.034854   0.000000
# Veillonella sp. 3_1_44                       0.000000   0.027008   0.000000
# Veillonella sp. 6_1_27                       0.005661   0.002326   0.019633
# Veillonella sp. ICM51a                       0.000000   0.026006   0.000085
#
#                                            HC-3-post  OSCC-1-post  \
# groups
# Acidovorax sp. MR-S7                        0.000000     0.000061
# Acinetobacter sp. 1578804                   0.002212     0.000000
# Actinomyces dentalis DSM 19115              0.000148     0.000135
# Actinomyces sp. ICM47                       0.014678     0.000000
# Actinomyces sp. oral taxon 180 str. F0310   0.001218     0.000086
# ...                                              ...          ...
# Streptomyces griseorubens                   0.000485     0.000000
# Tyzzerella nexilis DSM 1787                 0.000000     0.000000
# Veillonella sp. 3_1_44                      0.000000     0.000000
# Veillonella sp. 6_1_27                      0.007102     0.000699
# Veillonella sp. ICM51a                      0.000726     0.000000
#
#                                            OSCC-2-post  OSCC-3-post  \
# groups
# Acidovorax sp. MR-S7                          0.000079     0.000000
# Acinetobacter sp. 1578804                     0.002069     0.000000
# Actinomyces dentalis DSM 19115                0.000000     0.000093
# Actinomyces sp. ICM47                         0.000826     0.000226
# Actinomyces sp. oral taxon 180 str. F0310     0.000029     0.007072
# ...                                                ...          ...
# Streptomyces griseorubens                     0.000000     0.000000
# Tyzzerella nexilis DSM 1787                   0.000000     0.000000
# Veillonella sp. 3_1_44                        0.000000     0.000000
# Veillonella sp. 6_1_27                        0.006562     0.175269
# Veillonella sp. ICM51a                        0.000530     0.000000
#
#                                            OSCC-4-post
# groups
# Acidovorax sp. MR-S7                          0.000000
# Acinetobacter sp. 1578804                     0.000000
# Actinomyces dentalis DSM 19115                0.000000
# Actinomyces sp. ICM47                         0.000000
# Actinomyces sp. oral taxon 180 str. F0310     0.000000
# ...                                                ...
# Streptomyces griseorubens                     0.000000
# Tyzzerella nexilis DSM 1787                   0.000000
# Veillonella sp. 3_1_44                        0.000000
# Veillonella sp. 6_1_27                        0.012815
# Veillonella sp. ICM51a                        0.000000
#
# [109 rows x 14 columns]

# %%
#data1保存到txt文件
df2.to_csv('data1.txt',sep='\t',index=False)

# %%
df9 = pd.read_table('stat_res_oh_vs_oo1.csv',sep=',',index_col=0)
df9
# Out:
#                                                baseMean  log2FoldChange  \
# groups
# Acidovorax sp. MR-S7                          70.841077       -4.599188
# Acinetobacter sp. 1578804                    206.088428       -0.116800
# Actinomyces dentalis DSM 19115                81.393050       -5.385373
# Actinomyces sp. ICM47                         71.193871        0.227164
# Actinomyces sp. oral taxon 180 str. F0310   4130.217744       -6.946758
# ...                                                 ...             ...
# Streptomyces griseorubens                      8.944966        0.975800
# Tyzzerella nexilis DSM 1787                   78.312080        4.743298
# Veillonella sp. 3_1_44                        78.312080        4.743298
# Veillonella sp. 6_1_27                     19640.974840       -7.625862
# Veillonella sp. ICM51a                        99.643639        2.469279
#
#                                               lfcSE      stat    pvalue  \
# groups
# Acidovorax sp. MR-S7                       1.832841 -2.509322       NaN
# Acinetobacter sp. 1578804                  1.761132 -0.066321       NaN
# Actinomyces dentalis DSM 19115             1.775725 -3.032775  0.002423
# Actinomyces sp. ICM47                      1.566317  0.145030  0.884687
# Actinomyces sp. oral taxon 180 str. F0310  2.082976 -3.335016       NaN
# ...                                             ...       ...       ...
# Streptomyces griseorubens                  1.542109  0.632770  0.526884
# Tyzzerella nexilis DSM 1787                2.129259  2.227675       NaN
# Veillonella sp. 3_1_44                     2.129259  2.227675       NaN
# Veillonella sp. 6_1_27                     2.103103 -3.626005       NaN
# Veillonella sp. ICM51a                     1.690328  1.460829  0.144062
#
#                                                padj
# groups
# Acidovorax sp. MR-S7                            NaN
# Acinetobacter sp. 1578804                       NaN
# Actinomyces dentalis DSM 19115             0.016301
# Actinomyces sp. ICM47                      0.962747
# Actinomyces sp. oral taxon 180 str. F0310       NaN
# ...                                             ...
# Streptomyces griseorubens                  0.695774
# Tyzzerella nexilis DSM 1787                     NaN
# Veillonella sp. 3_1_44                          NaN
# Veillonella sp. 6_1_27                          NaN
# Veillonella sp. ICM51a                     0.268406
#
# [109 rows x 6 columns]

# %%
df9.loc[(df9.log2FoldChange>7)&(df9.padj<0.05),'type']='up'
df9.loc[(df9.log2FoldChange<-7)&(df9.padj<0.05),'type']='down'
df9.loc[(abs(df9.log2FoldChange)<=7)|(df9.padj>=0.05),'type']='nosig'
df9
# Out:
#                                                baseMean  log2FoldChange  \
# groups
# Acidovorax sp. MR-S7                          70.841077       -4.599188
# Acinetobacter sp. 1578804                    206.088428       -0.116800
# Actinomyces dentalis DSM 19115                81.393050       -5.385373
# Actinomyces sp. ICM47                         71.193871        0.227164
# Actinomyces sp. oral taxon 180 str. F0310   4130.217744       -6.946758
# ...                                                 ...             ...
# Streptomyces griseorubens                      8.944966        0.975800
# Tyzzerella nexilis DSM 1787                   78.312080        4.743298
# Veillonella sp. 3_1_44                        78.312080        4.743298
# Veillonella sp. 6_1_27                     19640.974840       -7.625862
# Veillonella sp. ICM51a                        99.643639        2.469279
#
#                                               lfcSE      stat    pvalue  \
# groups
# Acidovorax sp. MR-S7                       1.832841 -2.509322       NaN
# Acinetobacter sp. 1578804                  1.761132 -0.066321       NaN
# Actinomyces dentalis DSM 19115             1.775725 -3.032775  0.002423
# Actinomyces sp. ICM47                      1.566317  0.145030  0.884687
# Actinomyces sp. oral taxon 180 str. F0310  2.082976 -3.335016       NaN
# ...                                             ...       ...       ...
# Streptomyces griseorubens                  1.542109  0.632770  0.526884
# Tyzzerella nexilis DSM 1787                2.129259  2.227675       NaN
# Veillonella sp. 3_1_44                     2.129259  2.227675       NaN
# Veillonella sp. 6_1_27                     2.103103 -3.626005       NaN
# Veillonella sp. ICM51a                     1.690328  1.460829  0.144062
#
#                                                padj   type
# groups
# Acidovorax sp. MR-S7                            NaN  nosig
# Acinetobacter sp. 1578804                       NaN  nosig
# Actinomyces dentalis DSM 19115             0.016301  nosig
# Actinomyces sp. ICM47                      0.962747  nosig
# Actinomyces sp. oral taxon 180 str. F0310       NaN  nosig
# ...                                             ...    ...
# Streptomyces griseorubens                  0.695774  nosig
# Tyzzerella nexilis DSM 1787                     NaN  nosig
# Veillonella sp. 3_1_44                          NaN  nosig
# Veillonella sp. 6_1_27                          NaN    NaN
# Veillonella sp. ICM51a                     0.268406  nosig
#
# [109 rows x 7 columns]

# %%
data1=df9

# %%
left1=data1
right1=df3
df10=pd.merge(left1, right1,on='groups')
df10
# Out:
#                                                baseMean  log2FoldChange  \
# groups
# Acidovorax sp. MR-S7                          70.841077       -4.599188
# Acinetobacter sp. 1578804                    206.088428       -0.116800
# Actinomyces dentalis DSM 19115                81.393050       -5.385373
# Actinomyces sp. ICM47                         71.193871        0.227164
# Actinomyces sp. oral taxon 180 str. F0310   4130.217744       -6.946758
# ...                                                 ...             ...
# Streptomyces griseorubens                      8.944966        0.975800
# Tyzzerella nexilis DSM 1787                   78.312080        4.743298
# Veillonella sp. 3_1_44                        78.312080        4.743298
# Veillonella sp. 6_1_27                     19640.974840       -7.625862
# Veillonella sp. ICM51a                        99.643639        2.469279
#
#                                               lfcSE      stat    pvalue  \
# groups
# Acidovorax sp. MR-S7                       1.832841 -2.509322       NaN
# Acinetobacter sp. 1578804                  1.761132 -0.066321       NaN
# Actinomyces dentalis DSM 19115             1.775725 -3.032775  0.002423
# Actinomyces sp. ICM47                      1.566317  0.145030  0.884687
# Actinomyces sp. oral taxon 180 str. F0310  2.082976 -3.335016       NaN
# ...                                             ...       ...       ...
# Streptomyces griseorubens                  1.542109  0.632770  0.526884
# Tyzzerella nexilis DSM 1787                2.129259  2.227675       NaN
# Veillonella sp. 3_1_44                     2.129259  2.227675       NaN
# Veillonella sp. 6_1_27                     2.103103 -3.626005       NaN
# Veillonella sp. ICM51a                     1.690328  1.460829  0.144062
#
#                                                padj   type  HC-1-pre  \
# groups
# Acidovorax sp. MR-S7                            NaN  nosig  0.003129
# Acinetobacter sp. 1578804                       NaN  nosig  0.000908
# Actinomyces dentalis DSM 19115             0.016301  nosig  0.000163
# Actinomyces sp. ICM47                      0.962747  nosig  0.025993
# Actinomyces sp. oral taxon 180 str. F0310       NaN  nosig  0.000505
# ...                                             ...    ...       ...
# Streptomyces griseorubens                  0.695774  nosig  0.005394
# Tyzzerella nexilis DSM 1787                     NaN  nosig  0.020114
# Veillonella sp. 3_1_44                          NaN  nosig  0.017882
# Veillonella sp. 6_1_27                          NaN    NaN  0.001250
# Veillonella sp. ICM51a                     0.268406  nosig  0.014210
#
#                                            HC-2-pre  HC-3-pre  ...  \
# groups                                                         ...
# Acidovorax sp. MR-S7                       0.001692  0.005346  ...
# Acinetobacter sp. 1578804                  0.000532  0.003437  ...
# Actinomyces dentalis DSM 19115             0.006459  0.006000  ...
# Actinomyces sp. ICM47                      0.009780  0.129033  ...
# Actinomyces sp. oral taxon 180 str. F0310  0.004907  0.004387  ...
# ...                                             ...       ...  ...
# Streptomyces griseorubens                  0.005589  0.042350  ...
# Tyzzerella nexilis DSM 1787                0.000000  0.000000  ...
# Veillonella sp. 3_1_44                     0.000000  0.000000  ...
# Veillonella sp. 6_1_27                     0.013667  0.008315  ...
# Veillonella sp. ICM51a                     0.002008  0.001763  ...
#
#                                            OSCC-2-pre  OSCC-3-pre  OSCC-4-pre  \
# groups
# Acidovorax sp. MR-S7                         0.008032    0.000000    0.009702
# Acinetobacter sp. 1578804                    0.012538    0.001411    0.001305
# Actinomyces dentalis DSM 19115               0.000000    0.021742    0.038357
# Actinomyces sp. ICM47                        0.005167    0.001578    0.000352
# Actinomyces sp. oral taxon 180 str. F0310    0.005223    0.032384    0.001295
# ...                                               ...         ...         ...
# Streptomyces griseorubens                    0.004618    0.003761    0.001960
# Tyzzerella nexilis DSM 1787                  0.000000    0.000000    0.001963
# Veillonella sp. 3_1_44                       0.000000    0.000000    0.000000
# Veillonella sp. 6_1_27                       0.001141    0.087272    0.005661
# Veillonella sp. ICM51a                       0.000417    0.000000    0.000000
#
#                                            HC-1-post  HC-2-post  HC-3-post  \
# groups
# Acidovorax sp. MR-S7                        0.000266   0.000000   0.000000
# Acinetobacter sp. 1578804                   0.002766   0.000738   0.002212
# Actinomyces dentalis DSM 19115              0.000340   0.000000   0.000148
# Actinomyces sp. ICM47                       0.010164   0.001300   0.014678
# Actinomyces sp. oral taxon 180 str. F0310   0.000952   0.000836   0.001218
# ...                                              ...        ...        ...
# Streptomyces griseorubens                   0.000286   0.000154   0.000485
# Tyzzerella nexilis DSM 1787                 0.034854   0.000000   0.000000
# Veillonella sp. 3_1_44                      0.027008   0.000000   0.000000
# Veillonella sp. 6_1_27                      0.002326   0.019633   0.007102
# Veillonella sp. ICM51a                      0.026006   0.000085   0.000726
#
#                                            OSCC-1-post  OSCC-2-post  \
# groups
# Acidovorax sp. MR-S7                          0.000061     0.000079
# Acinetobacter sp. 1578804                     0.000000     0.002069
# Actinomyces dentalis DSM 19115                0.000135     0.000000
# Actinomyces sp. ICM47                         0.000000     0.000826
# Actinomyces sp. oral taxon 180 str. F0310     0.000086     0.000029
# ...                                                ...          ...
# Streptomyces griseorubens                     0.000000     0.000000
# Tyzzerella nexilis DSM 1787                   0.000000     0.000000
# Veillonella sp. 3_1_44                        0.000000     0.000000
# Veillonella sp. 6_1_27                        0.000699     0.006562
# Veillonella sp. ICM51a                        0.000000     0.000530
#
#                                            OSCC-3-post  OSCC-4-post
# groups
# Acidovorax sp. MR-S7                          0.000000     0.000000
# Acinetobacter sp. 1578804                     0.000000     0.000000
# Actinomyces dentalis DSM 19115                0.000093     0.000000
# Actinomyces sp. ICM47                         0.000226     0.000000
# Actinomyces sp. oral taxon 180 str. F0310     0.007072     0.000000
# ...                                                ...          ...
# Streptomyces griseorubens                     0.000000     0.000000
# Tyzzerella nexilis DSM 1787                   0.000000     0.000000
# Veillonella sp. 3_1_44                        0.000000     0.000000
# Veillonella sp. 6_1_27                        0.175269     0.012815
# Veillonella sp. ICM51a                        0.000000     0.000000
#
# [109 rows x 21 columns]

# %%
#筛选df12中type的up和down的行
df13=df10[(df10.type=='up')|(df10.type=='down')]
df13
# Out:
#                                      baseMean  log2FoldChange     lfcSE  \
# groups
# Alloscardovia omnicolens F0580   15528.369583      -18.264743  2.427840
# Enterobacter cloacae             30324.130639       -8.925053  1.784886
# Gemella morbillorum M424         12436.955442       -7.837129  1.773972
# Klebsiella pneumoniae            27728.131591       -7.727925  1.784944
# Prevotella aurantiaca JCM 15754    484.826729        7.572749  1.648054
# Prevotella intermedia 17           460.506607        7.500993  1.640847
#
#                                      stat        pvalue          padj  type  \
# groups
# Alloscardovia omnicolens F0580  -7.523043  5.351599e-14  3.960183e-12  down
# Enterobacter cloacae            -5.000348  5.722696e-07  2.117398e-05  down
# Gemella morbillorum M424        -4.417841  9.969156e-06  1.475435e-04  down
# Klebsiella pneumoniae           -4.329505  1.494447e-05  1.843151e-04  down
# Prevotella aurantiaca JCM 15754  4.594963  4.328261e-06  8.962173e-05    up
# Prevotella intermedia 17         4.571415  4.844418e-06  8.962173e-05    up
#
#                                  HC-1-pre  HC-2-pre  HC-3-pre  ...  \
# groups                                                         ...
# Alloscardovia omnicolens F0580   0.000000  0.000000  0.000000  ...
# Enterobacter cloacae             0.000000  0.000221  0.000000  ...
# Gemella morbillorum M424         0.001692  0.000728  0.010409  ...
# Klebsiella pneumoniae            0.000064  0.000292  0.000000  ...
# Prevotella aurantiaca JCM 15754  0.017227  0.028010  0.038742  ...
# Prevotella intermedia 17         0.008800  0.011247  0.015976  ...
#
#                                  OSCC-2-pre  OSCC-3-pre  OSCC-4-pre  \
# groups
# Alloscardovia omnicolens F0580     0.000000     0.00000    0.000294
# Enterobacter cloacae               0.000000     0.00000    0.000022
# Gemella morbillorum M424           0.005128     0.00287    0.006632
# Klebsiella pneumoniae              0.000000     0.00000    0.000030
# Prevotella aurantiaca JCM 15754    0.000000     0.00000    0.000000
# Prevotella intermedia 17           0.000299     0.00000    0.000000
#
#                                  HC-1-post  HC-2-post  HC-3-post  OSCC-1-post  \
# groups
# Alloscardovia omnicolens F0580    0.000000   0.000000   0.000000     0.008919
# Enterobacter cloacae              0.001369   0.035728   0.001758     0.480295
# Gemella morbillorum M424          0.002025   0.000000   0.001493     0.003807
# Klebsiella pneumoniae             0.002994   0.075998   0.002649     0.152785
# Prevotella aurantiaca JCM 15754   0.029889   0.015225   0.038405     0.000000
# Prevotella intermedia 17          0.014061   0.005723   0.016707     0.000000
#
#                                  OSCC-2-post  OSCC-3-post  OSCC-4-post
# groups
# Alloscardovia omnicolens F0580      0.000000     0.002797     0.000000
# Enterobacter cloacae                0.151704     0.290399     0.352427
# Gemella morbillorum M424            0.000905     0.000500     0.006642
# Klebsiella pneumoniae               0.316935     0.306104     0.486863
# Prevotella aurantiaca JCM 15754     0.000000     0.000000     0.000000
# Prevotella intermedia 17            0.000000     0.000000     0.000000
#
# [6 rows x 21 columns]

# %%
df15=df13[['type','HC-1-post','HC-2-post',  'HC-3-post',
'OSCC-1-post','OSCC-2-post','OSCC-3-post',  'OSCC-4-post']]
df15
# Out:
#                                  type  HC-1-post  HC-2-post  HC-3-post  \
# groups
# Alloscardovia omnicolens F0580   down   0.000000   0.000000   0.000000
# Enterobacter cloacae             down   0.001369   0.035728   0.001758
# Gemella morbillorum M424         down   0.002025   0.000000   0.001493
# Klebsiella pneumoniae            down   0.002994   0.075998   0.002649
# Prevotella aurantiaca JCM 15754    up   0.029889   0.015225   0.038405
# Prevotella intermedia 17           up   0.014061   0.005723   0.016707
#
#                                  OSCC-1-post  OSCC-2-post  OSCC-3-post  \
# groups
# Alloscardovia omnicolens F0580      0.008919     0.000000     0.002797
# Enterobacter cloacae                0.480295     0.151704     0.290399
# Gemella morbillorum M424            0.003807     0.000905     0.000500
# Klebsiella pneumoniae               0.152785     0.316935     0.306104
# Prevotella aurantiaca JCM 15754     0.000000     0.000000     0.000000
# Prevotella intermedia 17            0.000000     0.000000     0.000000
#
#                                  OSCC-4-post
# groups
# Alloscardovia omnicolens F0580      0.000000
# Enterobacter cloacae                0.352427
# Gemella morbillorum M424            0.006642
# Klebsiella pneumoniae               0.486863
# Prevotella aurantiaca JCM 15754     0.000000
# Prevotella intermedia 17            0.000000

# %%
#检查df15中索引是否有重复
df15.index.is_unique
# Out:
# True

# %%
df15
# Out:
#                                  type  HC-1-post  HC-2-post  HC-3-post  \
# groups
# Alloscardovia omnicolens F0580   down   0.000000   0.000000   0.000000
# Enterobacter cloacae             down   0.001369   0.035728   0.001758
# Gemella morbillorum M424         down   0.002025   0.000000   0.001493
# Klebsiella pneumoniae            down   0.002994   0.075998   0.002649
# Prevotella aurantiaca JCM 15754    up   0.029889   0.015225   0.038405
# Prevotella intermedia 17           up   0.014061   0.005723   0.016707
#
#                                  OSCC-1-post  OSCC-2-post  OSCC-3-post  \
# groups
# Alloscardovia omnicolens F0580      0.008919     0.000000     0.002797
# Enterobacter cloacae                0.480295     0.151704     0.290399
# Gemella morbillorum M424            0.003807     0.000905     0.000500
# Klebsiella pneumoniae               0.152785     0.316935     0.306104
# Prevotella aurantiaca JCM 15754     0.000000     0.000000     0.000000
# Prevotella intermedia 17            0.000000     0.000000     0.000000
#
#                                  OSCC-4-post
# groups
# Alloscardovia omnicolens F0580      0.000000
# Enterobacter cloacae                0.352427
# Gemella morbillorum M424            0.006642
# Klebsiella pneumoniae               0.486863
# Prevotella aurantiaca JCM 15754     0.000000
# Prevotella intermedia 17            0.000000

# %%
df11=df15[['HC-1-post','HC-2-post',  'HC-3-post',
'OSCC-1-post','OSCC-2-post','OSCC-3-post',  'OSCC-4-post']]
df11
# Out:
#                                  HC-1-post  HC-2-post  HC-3-post  OSCC-1-post  \
# groups
# Alloscardovia omnicolens F0580    0.000000   0.000000   0.000000     0.008919
# Enterobacter cloacae              0.001369   0.035728   0.001758     0.480295
# Gemella morbillorum M424          0.002025   0.000000   0.001493     0.003807
# Klebsiella pneumoniae             0.002994   0.075998   0.002649     0.152785
# Prevotella aurantiaca JCM 15754   0.029889   0.015225   0.038405     0.000000
# Prevotella intermedia 17          0.014061   0.005723   0.016707     0.000000
#
#                                  OSCC-2-post  OSCC-3-post  OSCC-4-post
# groups
# Alloscardovia omnicolens F0580      0.000000     0.002797     0.000000
# Enterobacter cloacae                0.151704     0.290399     0.352427
# Gemella morbillorum M424            0.000905     0.000500     0.006642
# Klebsiella pneumoniae               0.316935     0.306104     0.486863
# Prevotella aurantiaca JCM 15754     0.000000     0.000000     0.000000
# Prevotella intermedia 17            0.000000     0.000000     0.000000

# %%
data0=np.log2(df11+0.0001)
data0
# Out:
#                                  HC-1-post  HC-2-post  HC-3-post  OSCC-1-post  \
# groups
# Alloscardovia omnicolens F0580  -13.287712 -13.287712 -13.287712    -6.792888
# Enterobacter cloacae             -9.410547  -4.802750  -9.072121    -1.057706
# Gemella morbillorum M424         -8.878092 -13.287712  -9.293866    -7.999612
# Klebsiella pneumoniae            -8.336109  -3.715989  -8.507021    -2.709477
# Prevotella aurantiaca JCM 15754  -5.059431  -6.027949  -4.698819   -13.287712
# Prevotella intermedia 17         -6.141896  -7.424004  -5.894804   -13.287712
#
#                                  OSCC-2-post  OSCC-3-post  OSCC-4-post
# groups
# Alloscardovia omnicolens F0580    -13.287712    -8.430991   -13.287712
# Enterobacter cloacae               -2.719718    -1.783394    -1.504193
# Gemella morbillorum M424           -9.958229   -10.703921    -7.212647
# Klebsiella pneumoniae              -1.657288    -1.707436    -1.038115
# Prevotella aurantiaca JCM 15754   -13.287712   -13.287712   -13.287712
# Prevotella intermedia 17          -13.287712   -13.287712   -13.287712

# %%
#查找表格是否有缺失值
data0.isnull().sum()
# Out:
# HC-1-post      0
# HC-2-post      0
# HC-3-post      0
# OSCC-1-post    0
# OSCC-2-post    0
# OSCC-3-post    0
# OSCC-4-post    0
# dtype: int64

# %%
print(data0.describe())
# Out:
#        HC-1-post  HC-2-post  HC-3-post  OSCC-1-post  OSCC-2-post  OSCC-3-post  \
# count   6.000000   6.000000   6.000000     6.000000     6.000000     6.000000
# mean   -8.518965  -8.091020  -8.459057    -7.522518    -9.033062    -8.200195
# std     2.874617   4.211081   3.003523     5.141869     5.466671     5.318249
# min   -13.287712 -13.287712 -13.287712   -13.287712   -13.287712   -13.287712
# 25%    -9.277433 -11.821785  -9.238430   -11.965687   -13.287712   -12.641765
# 50%    -8.607101  -6.725977  -8.789571    -7.396250   -11.622971    -9.567456
# 75%    -6.690450  -5.109050  -6.547858    -3.730330    -4.529346    -3.445293
# max    -5.059431  -3.715989  -4.698819    -1.057706    -1.657288    -1.707436
#
#        OSCC-4-post
# count     6.000000
# mean     -8.269682
# std       5.911457
# min     -13.287712
# 25%     -13.287712
# 50%     -10.250180
# 75%      -2.931307
# max      -1.038115

# %%
data0 = data0 + np.random.normal(0, 1e-4, data0.shape)

# %%
print(data0.describe())
# Out:
#        HC-1-post  HC-2-post  HC-3-post  OSCC-1-post  OSCC-2-post  OSCC-3-post  \
# count   6.000000   6.000000   6.000000     6.000000     6.000000     6.000000
# mean   -8.518944  -8.091044  -8.459063    -7.522512    -9.033036    -8.200255
# std     2.874612   4.211046   3.003546     5.141775     5.466615     5.318210
# min   -13.287747 -13.287789 -13.287786   -13.287613   -13.287676   -13.287806
# 25%    -9.277265 -11.821715  -9.238436   -11.965553   -13.287613   -12.641773
# 50%    -8.607122  -6.725988  -8.789528    -7.396294   -11.622930    -9.567466
# 75%    -6.690507  -5.109117  -6.547895    -3.730440    -4.529297    -3.445487
# max    -5.059392  -3.716047  -4.698781    -1.057745    -1.657421    -1.707422
#
#        OSCC-4-post
# count     6.000000
# mean     -8.269708
# std       5.911391
# min     -13.287749
# 25%     -13.287682
# 50%     -10.250131
# 75%      -2.931425
# max      -1.038182

# %%
df16=df15[['type']]
df16
# Out:
#                                  type
# groups
# Alloscardovia omnicolens F0580   down
# Enterobacter cloacae             down
# Gemella morbillorum M424         down
# Klebsiella pneumoniae            down
# Prevotella aurantiaca JCM 15754    up
# Prevotella intermedia 17           up

# %%
#df16的type列名称改为P&log2FC
df16.columns=['Change']
data_rows=df16
data_rows
# Out:
#                                 Change
# groups
# Alloscardovia omnicolens F0580    down
# Enterobacter cloacae              down
# Gemella morbillorum M424          down
# Klebsiella pneumoniae             down
# Prevotella aurantiaca JCM 15754     up
# Prevotella intermedia 17            up

# %%
data_cols=pd.read_csv('group22.tsv',index_col=0, sep='\t')
data_cols
# Out:
#                          Group
# sample
# HC-1-post      HC-post-culture
# HC-2-post      HC-post-culture
# HC-3-post      HC-post-culture
# OSCC-1-post  OSCC-post-culture
# OSCC-2-post  OSCC-post-culture
# OSCC-3-post  OSCC-post-culture
# OSCC-4-post  OSCC-post-culture

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import pandas as pd
import os
import PyComplexHeatmap as pchm
from PyComplexHeatmap import *

# %%
row_ha_left = HeatmapAnnotation(
                            Change =anno_simple(data_rows['Change'],colors={'up': 'red', 'down': 'green'},
                                                add_text=True,legend=False,height=5,
                                                text_kws={'color':'white', 'fontsize':12,'fontweight':'bold',
                                                          'rotation':-90,'horizontalalignment':'left'}),
                            label_kws={'fontsize':16,'color':'black','rotation':-45,'horizontalalignment':'left'},
                            label_side='bottom',axis=0,verbose=0
                            )
col_ha = HeatmapAnnotation(Group=data_cols.Group,label_side='right', axis=1,label_kws={'fontsize': 16})
plt.figure(figsize=(10, 7))
cm = ClusterMapPlotter(data=data0,left_annotation=row_ha_left,top_annotation=col_ha,
                       show_rownames=True, show_colnames=True,col_names_side='bottom',
                       row_split=data_rows.Change, cmap='YlGnBu',
                       rasterized=True, legend=True,
                       xticklabels_kws={'labelrotation':-20,'labelsize': 15}, yticklabels_kws={'labelsize': 15},row_dendrogram=True,col_dendrogram=True)
plt.title('HC-post-culture vs OSCC-post-culture', fontsize=17, loc='center', x=-39, y=4)
plt.savefig('heatmap of HC-post-culture vs OSCC-post-culture1.pdf',dpi=300,bbox_inches='tight')
plt.show()
# Out:
# Starting plotting..
# Starting calculating row orders..
# Reordering rows..
# Starting calculating col orders..
# Reordering cols..
# Plotting matrix..
# Starting plotting HeatmapAnnotations
# Collecting legends..
# Collecting annotation legends..
# Plotting legends..
# Estimated legend width: 41.981944444444444 mm
